# %%
import pandas as pd
import numpy as np
import pickle
import csv
import os
import time

# %%
from google.colab import drive, auth

# %%
print(auth.authenticate_user(project_id='mit-mlhc'))

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# None
# Mounted at /content/drive

# %%
import gspread
from google.auth import default
creds, _ = default()

# %%
gc = gspread.authorize(creds)

# %%
path_to_worksheet = 'MCQ2.0'
worksheet = gc.open(path_to_worksheet).sheet1
rows = worksheet.get_all_values()
prompt_df = pd.DataFrame.from_records(rows)
prompt_df.columns = prompt_df.iloc[0]  # Set the first row as column names
prompt_df.drop(prompt_df.index[0], inplace=True)  # Drop the first row since it's now the header
prompt_df
# Out:
# 0   question_id        source  labels                             topic  \
# 1            1a         apdvs  cs, lq                 carotid disorders
# 2            1b         apdvs  cs, sq                 carotid disorders
# 3            2a         apdvs  gk, lq                 carotid disorders
# 4            2b         apdvs  gk, sq                 carotid disorders
# 5            3a         apdvs  gk, lq  lower extremity arterial disease
# ..          ...           ...     ...                               ...
# 447      56.ten  case_studies      cs                   venuous disease
# 448        57.2  case_studies      gk                   venuous disease
# 449        57.3  case_studies      gk                   venuous disease
# 450        57.4  case_studies      gk                   venuous disease
# 451        57.5  case_studies      gk                   venuous disease
#
# 0                                             question   answer  \
# 1    A 75-year-old male smoke presents with recent ...        D
# 2    A 75-year-old man had temporary vision loss in...        D
# 3     What is the first muscle layer encountered in...        C
# 4    During a carotid endarterectomy, which neck mu...        C
# 5     A 65-year old male with a history of hyperten...        B
# ..                                                 ...      ...
# 447  A 19 year old female was brought in to the Eme...        C
# 448  Which of the following statements regarding th...  B, C, E
# 449  Which of the following statements regarding th...  A, B, D
# 450  What are the long-term results of derivative a...     A, C
# 451  Which of the following statements are true? se...     B, C
#
# 0                                          explanation
# 1    Right carotid endarterectomy. The patient has ...
# 2    Right carotid endarterectomy. The patient has ...
# 3    The platysma is the most superficial muscle in...
# 4    The platysma is the most superficial muscle in...
# 5    Claudication is defined as reproducible pain o...
# ..                                                 ...
# 447
# 448
# 449
# 450
# 451
#
# [451 rows x 7 columns]

# %%
id_question = {}
for row in prompt_df.iterrows():
  id_question[row[1]["question_id"]] = row[1]

# %%
pre_prompts = {
1: "",
2: """You are a vascular surgeon responsible for teaching medical students. Provide concise, medically accurate, and ethically appropriate answers based on current standards of care. Focus only on clinical education relevant to surgery.""",
3: """You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students. Provide useful, complete, and scientifically-grounded answers to clinical questions relevant to surgery and medical care.""",
4: """Answer the following multiple choice question from the medical domain based on these instructions. Choose one or more of the provided answer choices which are correct and output them under the heading "Answer".""",
5: """You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students.
Answer the following multiple choice question from the medical domain based on the following instructions.
1. Select the one or more correct options and provide the option(s) under the heading "Answer".
2. Always select one or more of the provided options as the answer.
3. If the options are ambiguous or the question does not have enough context, select the ones that best answer the question.
4. If the question is not clinically relevant to vascular surgery, please respond with, "I'm sorry, I cannot answer this question." """
}

few_shot = """Question:
Which of the following is the most common site for peripheral arterial disease (PAD)?
A. Carotid artery
B. Femoral-popliteal artery
C. Renal artery
D. Subclavian artery
Answer:
B. Femoral-popliteal artery

Question:
Which of the following are common risk factors for developing an abdominal aortic aneurysm (AAA)?
A. Smoking
B. Male gender
C. Hypertension
D. Type 1 diabetes mellitus
E. Family history of AAA
Answer:
A. Smoking
B. Male gender
C. Hypertension
E. Family history of AAA
"""

pre_prompts[6] = few_shot

# %%
# final prompts
pre_prompts = {
1: "",
2: """You are a vascular surgeon responsible for teaching medical students. Provide concise, medically accurate, and ethically appropriate answers based on current standards of care. Focus only on clinical education relevant to surgery.""",
3: """You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students. Provide useful, complete, and scientifically-grounded answers to clinical questions relevant to surgery and medical care.""",
4: """Answer the following multiple choice question from the medical domain based on these instructions. Choose one or more of the provided answer choices which are correct and output them under the heading "Answer".""",
5: """You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students.
Answer the following multiple choice question from the medical domain based on the following instructions.
1. Select the one or more correct options and provide the option(s) under the heading "Answer".
2. Always select one or more of the provided options as the answer.
3. If the options are ambiguous or the question does not have enough context, select the ones that best answer the question.
4. If the question is not clinically relevant to vascular surgery, please respond with, "I'm sorry, I cannot answer this question." """
}

few_shot = """Question:
Which of the following is the most common site for peripheral arterial disease (PAD)?
A. Carotid artery
B. Femoral-popliteal artery
C. Renal artery
D. Subclavian artery
Answer:
B. Femoral-popliteal artery

Question:
Which of the following are common risk factors for developing an abdominal aortic aneurysm (AAA)?
A. Smoking
B. Male gender
C. Hypertension
D. Type 1 diabetes mellitus
E. Family history of AAA
Answer:
A. Smoking
B. Male gender
C. Hypertension
E. Family history of AAA
"""

pre_prompts[6] = few_shot

# %%
print(f'{changed_qids = }')
# Out:
# changed_qids = ['5a', '75', '90', '369', '399', '402', '404', '433', '14.6', '18.2', '18.3', '18.4', '18.5', '18.7', '18.8', '18.9', '18.ten', '20.1', '21.5', '27.1', '27.5', '27.6', '27.8', '27.9', '27.ten', '27.11', '32.1', '32.7', '37.1', '37.2', '37.3', '42.5', '43.9', '43.ten', '46.5', '48.5', '49.5', '49.8', '49.9', '53.5']

# %%
models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2", "microsoft/Phi-4-mini-instruct", "gemini-2.0-flash-001"]

# %%
p_toks = {}
model_toks = {}
model_name = models[0]
for model_name, tokenizer in model_tok.items():
  for prompt in id_question.values():
    key = (prompt["prompt_id"], prompt["question_id"], model_name)
    query = prompt["query"]['content']
    tokens = tokenizer(query)
    print(tokens)
    num_toks = len(tokens['input_ids'])
    p_toks[key] = (tokens, num_toks)
    model_toks.setdefault(model_name, []).append(num_toks)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1
worksheet.append_row(["prompt_id", "question_id", "model", "answer", "response", "correct"])
# Out:
# {'spreadsheetId': '1kUPTZMyOBMOp6C8EGnCybytruMc-A3tGPh-Kfxpo2nU',
#  'updates': {'spreadsheetId': '1kUPTZMyOBMOp6C8EGnCybytruMc-A3tGPh-Kfxpo2nU',
#   'updatedRange': 'Sheet1!A1:F1',
#   'updatedRows': 1,
#   'updatedColumns': 6,
#   'updatedCells': 6}}

# %%
path_to_worksheet = 'MCQ2.0'
worksheet = gc.open(path_to_worksheet).get_worksheet(4)
rows = worksheet.get_all_values()
eval_df = pd.DataFrame.from_records(rows)
eval_df.columns = eval_df.iloc[0]  # Set the first row as column names
eval_df.drop(eval_df.index[0], inplace=True)  # Drop the first row since it's now the header
eval_df
# Out:
# 0    prompt_id question_id                            model  \
# 1            2         10a  FreedomIntelligence/Apollo-0.5B
# 2            3         10a  FreedomIntelligence/Apollo-0.5B
# 3            4         10a  FreedomIntelligence/Apollo-0.5B
# 4            5         10a  FreedomIntelligence/Apollo-0.5B
# 5            6         10a  FreedomIntelligence/Apollo-0.5B
# ...        ...         ...                              ...
# 2550         6          9b          skumar9/Llama-medx_v3.2
# 2551         5          9b          skumar9/Llama-medx_v3.2
# 2552         2          9b          skumar9/Llama-medx_v3.2
# 2553         3          9b          skumar9/Llama-medx_v3.2
# 2554         4          9b          skumar9/Llama-medx_v3.2
#
# 0                                                answer  \
# 1     A. Using anatomic landmarks to confirm cannula...
# 2     A. Using anatomic landmarks to confirm cannula...
# 3     A. Using anatomic landmarks to confirm cannula...
# 4     A. Using anatomic landmarks to confirm cannula...
# 5     A. Using anatomic landmarks to confirm cannula...
# ...                                                 ...
# 2550  C. Consider endovenous ablation of refluxing s...
# 2551  C. Consider endovenous ablation of refluxing s...
# 2552  C. Consider endovenous ablation of refluxing s...
# 2553  C. Consider endovenous ablation of refluxing s...
# 2554  C. Consider endovenous ablation of refluxing s...
#
# 0                                              response correct
# 1     ### Instructions\nYou are a vascular surgeon r...       Y
# 2     ### Correct Answer: D. Using the Seldinger tec...       N
# 3     D. Using the Seldinger technique for first acc...       N
# 4     ### Correct Answer:\nD. Using the Seldinger te...       N
# 5     ### Instructions\nQuestion:\nWhich of the foll...       N
# ...                                                 ...     ...
# 2550  B Perform surgical ligation of perforator vein...       N
# 2551  C Consider endovenous ablation of refluxing su...       Y
# 2552  C Consider endovenous ablation of refluxing su...       Y
# 2553  C Consider endovenous ablation of refluxing su...       Y
# 2554  B Perform surgical ligation of perforator vein...       N
#
# [2554 rows x 6 columns]

# %%
# Do some stats stuff

path_to_worksheet = 'MCQ2.0'
worksheet = gc.open(path_to_worksheet).get_worksheet(3)
rows = worksheet.get_all_values()
eval_df2 = pd.DataFrame.from_records(rows)
eval_df2.columns = eval_df2.iloc[0]  # Set the first row as column names
eval_df2.drop(eval_df2.index[0], inplace=True)  # Drop the first row since it's now the header
eval_df2
# Out:
# 0    prompt_id question_id                    model  \
# 1            1         423  skumar9/Llama-medx_v3.2
# 2            1        28.3  skumar9/Llama-medx_v3.2
# 3            1        56.8  skumar9/Llama-medx_v3.2
# 4            1          75  skumar9/Llama-medx_v3.2
# 5            1        30.5  skumar9/Llama-medx_v3.2
# ...        ...         ...                      ...
# 2251         1        35.4     gemini-2.0-flash-001
# 2252         1         373     gemini-2.0-flash-001
# 2253         1         11a     gemini-2.0-flash-001
# 2254         1        57.3     gemini-2.0-flash-001
# 2255         1        57.2     gemini-2.0-flash-001
#
# 0                                                answer  \
# 1     A. Aortic stent graft.\n B. PTA and stenting o...
# 2     A. The best patency can be achieved using a ve...
# 3                                B. Compression bandage
# 4                           D. Rupture of alveolar bleb
# 5     A. Regular clinic review with attention to med...
# ...                                                 ...
# 2251  C. When the carotid body tumor is growing, enc...
# 2252  C. Transfer to the operating room for emergent...
# 2253  C. Transfer to the operating room for emergent...
# 2254  A. Lymphangiography is currently the best diag...
# 2255  B. Duplex has an important role in determining...
#
# 0                                              response correct
# 1     D Extra-anatomic revascularization, e.g. femor...       N
# 2     D Conservative treatment with long term chroni...       N
# 3                             B Compression bandage [A]       Y
# 4                                   A Lung collapse [A]       N
# 5     A Regular clinic review with attention to medi...       Y
# ...                                                 ...     ...
# 2251  Let's analyze each statement:\n \n * **A. A Sh...       N
# 2252  The correct answer is **C. Transfer to the ope...       Y
# 2253  The correct answer is **C. Transfer to the ope...       Y
# 2254  Let's analyze each statement:\n \n * **A. Lymp...       N
# 2255  Let's analyze each statement:\n \n * **A. Lymp...       N
#
# [2255 rows x 6 columns]

# %%
model_qids = {}
model_prompts = {}
model_keys = {}
all_prompt_qs = set()

key_row = {}
for idx, row in eval_df.iterrows():
  assert row["correct"] == "Y" or row["correct"] == "N"
  mod = row["model"]
  qid = row["question_id"]
  model_qids.setdefault(mod, set()).add(qid)
  model_prompts.setdefault(mod, set()).add(row["prompt_id"])
  model_keys.setdefault(mod, set()).add((qid, row["prompt_id"]))
  key_row[(row["prompt_id"], qid, mod)] = row
  if row["prompt_id"] != "1":
    all_prompt_qs.add(row["question_id"])

for idx, row in eval_df2.iterrows():
  assert row["correct"] == "Y" or row["correct"] == "N", f'{row.to_dict()}'
  mod = row["model"]
  qid = row["question_id"]
  model_qids.setdefault(mod, set()).add(qid)
  model_prompts.setdefault(mod, set()).add(row["prompt_id"])
  model_keys.setdefault(mod, set()).add((qid, row["prompt_id"]))
  key_row[(row["prompt_id"], qid, mod)] = row

for model in model_qids:
  print(model, len(model_qids[model]))
  print(model, len(model_prompts[model]))
  print(model, len(model_keys[model]))
# Out:
# FreedomIntelligence/Apollo-0.5B 451
# FreedomIntelligence/Apollo-0.5B 6
# FreedomIntelligence/Apollo-0.5B 1286
# johnsnowlabs/JSL-MedPhi2-2.7B 451
# johnsnowlabs/JSL-MedPhi2-2.7B 6
# johnsnowlabs/JSL-MedPhi2-2.7B 1286
# skumar9/Llama-medx_v3.2 451
# skumar9/Llama-medx_v3.2 6
# skumar9/Llama-medx_v3.2 1286
# microsoft/Phi-4-mini-instruct 451
# microsoft/Phi-4-mini-instruct 1
# microsoft/Phi-4-mini-instruct 451
# gemini-2.0-flash-001 451
# gemini-2.0-flash-001 1
# gemini-2.0-flash-001 451

# %%
# overall accuracy
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
columns = ["Model", "Num Correct", "Num Questions", "% Accuracy"]
rows = []



for model in models:
  res = [row["correct"] == "Y" for row in key_row.values() if row["model"] == model]
  rows.append([model, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                              Model  Num Correct  Num Questions  % Accuracy
# 0  FreedomIntelligence/Apollo-0.5B          233           1286        18.1
# 1    johnsnowlabs/JSL-MedPhi2-2.7B          432           1286        33.6
# 2          skumar9/Llama-medx_v3.2          490           1286        38.1
# 3    microsoft/Phi-4-mini-instruct          195            451        43.2
# 4             gemini-2.0-flash-001          235            451        52.1

# %%
# base accuracy
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
columns = ["Model", "Num Correct", "Num Questions", "% Accuracy"]
rows = []

for model in models:
  res = [row["correct"] == "Y" for row in key_row.values() if row["model"] == model and row["prompt_id"]=="1"]
  rows.append([model, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                              Model  Num Correct  Num Questions  % Accuracy
# 0  FreedomIntelligence/Apollo-0.5B          109            451        24.2
# 1    johnsnowlabs/JSL-MedPhi2-2.7B          152            451        33.7
# 2          skumar9/Llama-medx_v3.2          162            451        35.9
# 3    microsoft/Phi-4-mini-instruct          195            451        43.2
# 4             gemini-2.0-flash-001          235            451        52.1

# %%
# make table
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
columns = ["Model", "Prompt", "Num Correct", "Num Questions", "% Accuracy"]
rows = []

for model in models:
  for prompt in pre_prompts:
    res = [row["correct"] == "Y" for row in key_row.values()
    if row["model"] == model and row["prompt_id"] == str(prompt) and row["question_id"] in all_prompt_qs]
    rows.append([model, prompt, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                               Model  Prompt  Num Correct  Num Questions  \
# 0   FreedomIntelligence/Apollo-0.5B       1           35            167
# 1   FreedomIntelligence/Apollo-0.5B       2           29            167
# 2   FreedomIntelligence/Apollo-0.5B       3           32            167
# 3   FreedomIntelligence/Apollo-0.5B       4           35            167
# 4   FreedomIntelligence/Apollo-0.5B       5           27            167
# 5   FreedomIntelligence/Apollo-0.5B       6            1            167
# 6     johnsnowlabs/JSL-MedPhi2-2.7B       1           52            167
# 7     johnsnowlabs/JSL-MedPhi2-2.7B       2           54            167
# 8     johnsnowlabs/JSL-MedPhi2-2.7B       3           56            167
# 9     johnsnowlabs/JSL-MedPhi2-2.7B       4           59            167
# 10    johnsnowlabs/JSL-MedPhi2-2.7B       5           55            167
# 11    johnsnowlabs/JSL-MedPhi2-2.7B       6           56            167
# 12          skumar9/Llama-medx_v3.2       1           63            167
# 13          skumar9/Llama-medx_v3.2       2           64            167
# 14          skumar9/Llama-medx_v3.2       3           73            167
# 15          skumar9/Llama-medx_v3.2       4           67            167
# 16          skumar9/Llama-medx_v3.2       5           65            167
# 17          skumar9/Llama-medx_v3.2       6           59            167
# 18    microsoft/Phi-4-mini-instruct       1           71            167
# 19    microsoft/Phi-4-mini-instruct       2            0              0
# 20    microsoft/Phi-4-mini-instruct       3            0              0
# 21    microsoft/Phi-4-mini-instruct       4            0              0
# 22    microsoft/Phi-4-mini-instruct       5            0              0
# 23    microsoft/Phi-4-mini-instruct       6            0              0
# 24             gemini-2.0-flash-001       1          105            167
# 25             gemini-2.0-flash-001       2            0              0
# 26             gemini-2.0-flash-001       3            0              0
# 27             gemini-2.0-flash-001       4            0              0
# 28             gemini-2.0-flash-001       5            0              0
# 29             gemini-2.0-flash-001       6            0              0
#
#     % Accuracy
# 0         21.0
# 1         17.4
# 2         19.2
# 3         21.0
# 4         16.2
# 5          0.6
# 6         31.1
# 7         32.3
# 8         33.5
# 9         35.3
# 10        32.9
# 11        33.5
# 12        37.7
# 13        38.3
# 14        43.7
# 15        40.1
# 16        38.9
# 17        35.3
# 18        42.5
# 19         0.0
# 20         0.0
# 21         0.0
# 22         0.0
# 23         0.0
# 24        62.9
# 25         0.0
# 26         0.0
# 27         0.0
# 28         0.0
# 29         0.0

# %%
columns = ["Model", "Source", "Num Correct", "Num Questions", "% Accuracy"]
rows = []
for source in sources:
  for model in models:


    res = [row["correct"] == "Y" for row in key_row.values()
    if row["model"] == model and id_question[row["question_id"]]["source"] == source and row["prompt_id"] == "1"]
    rows.append([model, source, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                               Model        Source  Num Correct  Num Questions  \
# 0   FreedomIntelligence/Apollo-0.5B  case_studies           77            317
# 1     johnsnowlabs/JSL-MedPhi2-2.7B  case_studies          102            317
# 2           skumar9/Llama-medx_v3.2  case_studies          109            317
# 3     microsoft/Phi-4-mini-instruct  case_studies          133            317
# 4              gemini-2.0-flash-001  case_studies          142            317
# 5   FreedomIntelligence/Apollo-0.5B         apdvs           26             61
# 6     johnsnowlabs/JSL-MedPhi2-2.7B         apdvs           34             61
# 7           skumar9/Llama-medx_v3.2         apdvs           39             61
# 8     microsoft/Phi-4-mini-instruct         apdvs           43             61
# 9              gemini-2.0-flash-001         apdvs           48             61
# 10  FreedomIntelligence/Apollo-0.5B          racs            2             56
# 11    johnsnowlabs/JSL-MedPhi2-2.7B          racs            8             56
# 12          skumar9/Llama-medx_v3.2          racs            4             56
# 13    microsoft/Phi-4-mini-instruct          racs            9             56
# 14             gemini-2.0-flash-001          racs           30             56
# 15  FreedomIntelligence/Apollo-0.5B          prep            4             13
# 16    johnsnowlabs/JSL-MedPhi2-2.7B          prep            7             13
# 17          skumar9/Llama-medx_v3.2          prep            9             13
# 18    microsoft/Phi-4-mini-instruct          prep            8             13
# 19             gemini-2.0-flash-001          prep           11             13
# 20  FreedomIntelligence/Apollo-0.5B          abvm            0              4
# 21    johnsnowlabs/JSL-MedPhi2-2.7B          abvm            1              4
# 22          skumar9/Llama-medx_v3.2          abvm            1              4
# 23    microsoft/Phi-4-mini-instruct          abvm            2              4
# 24             gemini-2.0-flash-001          abvm            4              4
#
#     % Accuracy
# 0         24.3
# 1         32.2
# 2         34.4
# 3         42.0
# 4         44.8
# 5         42.6
# 6         55.7
# 7         63.9
# 8         70.5
# 9         78.7
# 10         3.6
# 11        14.3
# 12         7.1
# 13        16.1
# 14        53.6
# 15        30.8
# 16        53.8
# 17        69.2
# 18        61.5
# 19        84.6
# 20         0.0
# 21        25.0
# 22        25.0
# 23        50.0
# 24       100.0

# %%
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
raw_tags = []
[raw_tags.extend([x.strip() for x in q["labels"].split(",")]) for q in id_question.values()]
tags = sorted(list(set(raw_tags)), key=lambda x: raw_tags.count(x), reverse=True)
print(tags)
columns = ["Model", "Tag", "Num Correct", "Num Questions", "% Accuracy"]
rows = []
for tag in tags:
  for model in models:

    res = [row["correct"] == "Y" for row in key_row.values()
    if row["model"] == model and tag in id_question[row["question_id"]]["labels"] and row["prompt_id"] == "1"]
    rows.append([model, tag, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
# ['gk', 'cs', 'sq', 'lq', 'fu']
#                               Model Tag  Num Correct  Num Questions  \
# 0   FreedomIntelligence/Apollo-0.5B  gk           40            235
# 1     johnsnowlabs/JSL-MedPhi2-2.7B  gk           62            235
# 2           skumar9/Llama-medx_v3.2  gk           65            235
# 3   FreedomIntelligence/Apollo-0.5B  cs           69            216
# 4     johnsnowlabs/JSL-MedPhi2-2.7B  cs           90            216
# 5           skumar9/Llama-medx_v3.2  cs           97            216
# 6   FreedomIntelligence/Apollo-0.5B  sq            7             13
# 7     johnsnowlabs/JSL-MedPhi2-2.7B  sq            9             13
# 8           skumar9/Llama-medx_v3.2  sq            8             13
# 9   FreedomIntelligence/Apollo-0.5B  lq            7             13
# 10    johnsnowlabs/JSL-MedPhi2-2.7B  lq            9             13
# 11          skumar9/Llama-medx_v3.2  lq           10             13
# 12  FreedomIntelligence/Apollo-0.5B  fu            1              2
# 13    johnsnowlabs/JSL-MedPhi2-2.7B  fu            1              2
# 14          skumar9/Llama-medx_v3.2  fu            2              2
#
#     % Accuracy
# 0         17.0
# 1         26.4
# 2         27.7
# 3         31.9
# 4         41.7
# 5         44.9
# 6         53.8
# 7         69.2
# 8         61.5
# 9         53.8
# 10        69.2
# 11        76.9
# 12        50.0
# 13        50.0
# 14       100.0

# %%
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
raw_topics = []
[raw_topics.extend([x.strip() for x in q["topic"].split(",")]) for q in id_question.values()]
topics = sorted(list(set(raw_topics)), key=lambda x: raw_topics.count(x), reverse=True)
print(topics)
columns = ["Model", "Topic", "Num Correct", "Num Questions", "% Accuracy"]
rows = []
for topic in topics:
  for model in models:

    res = [row["correct"] == "Y" for row in key_row.values()
    if row["model"] == model and topic == id_question[row["question_id"]]["topic"] and row["prompt_id"] == "1"]
    rows.append([model, topic, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
# ['lower extremity arterial disease', 'venuous disease', 'aortic disorders', 'other', 'carotid disorders', 'endovascular surgery']
#                               Model                             Topic  \
# 0   FreedomIntelligence/Apollo-0.5B  lower extremity arterial disease
# 1     johnsnowlabs/JSL-MedPhi2-2.7B  lower extremity arterial disease
# 2           skumar9/Llama-medx_v3.2  lower extremity arterial disease
# 3     microsoft/Phi-4-mini-instruct  lower extremity arterial disease
# 4              gemini-2.0-flash-001  lower extremity arterial disease
# 5   FreedomIntelligence/Apollo-0.5B                   venuous disease
# 6     johnsnowlabs/JSL-MedPhi2-2.7B                   venuous disease
# 7           skumar9/Llama-medx_v3.2                   venuous disease
# 8     microsoft/Phi-4-mini-instruct                   venuous disease
# 9              gemini-2.0-flash-001                   venuous disease
# 10  FreedomIntelligence/Apollo-0.5B                  aortic disorders
# 11    johnsnowlabs/JSL-MedPhi2-2.7B                  aortic disorders
# 12          skumar9/Llama-medx_v3.2                  aortic disorders
# 13    microsoft/Phi-4-mini-instruct                  aortic disorders
# 14             gemini-2.0-flash-001                  aortic disorders
# 15  FreedomIntelligence/Apollo-0.5B                             other
# 16    johnsnowlabs/JSL-MedPhi2-2.7B                             other
# 17          skumar9/Llama-medx_v3.2                             other
# 18    microsoft/Phi-4-mini-instruct                             other
# 19             gemini-2.0-flash-001                             other
# 20  FreedomIntelligence/Apollo-0.5B                 carotid disorders
# 21    johnsnowlabs/JSL-MedPhi2-2.7B                 carotid disorders
# 22          skumar9/Llama-medx_v3.2                 carotid disorders
# 23    microsoft/Phi-4-mini-instruct                 carotid disorders
# 24             gemini-2.0-flash-001                 carotid disorders
# 25  FreedomIntelligence/Apollo-0.5B              endovascular surgery
# 26    johnsnowlabs/JSL-MedPhi2-2.7B              endovascular surgery
# 27          skumar9/Llama-medx_v3.2              endovascular surgery
# 28    microsoft/Phi-4-mini-instruct              endovascular surgery
# 29             gemini-2.0-flash-001              endovascular surgery
#
#     Num Correct  Num Questions  % Accuracy
# 0            35            128        27.3
# 1            48            128        37.5
# 2            55            128        43.0
# 3            54            128        42.2
# 4            71            128        55.5
# 5            35            126        27.8
# 6            42            126        33.3
# 7            42            126        33.3
# 8            56            126        44.4
# 9            67            126        53.2
# 10           17            107        15.9
# 11           23            107        21.5
# 12           32            107        29.9
# 13           38            107        35.5
# 14           44            107        41.1
# 15            8             49        16.3
# 16           19             49        38.8
# 17           15             49        30.6
# 18           22             49        44.9
# 19           28             49        57.1
# 20           12             32        37.5
# 21           16             32        50.0
# 22           13             32        40.6
# 23           18             32        56.2
# 24           19             32        59.4
# 25            2              9        22.2
# 26            4              9        44.4
# 27            5              9        55.6
# 28            7              9        77.8
# 29            6              9        66.7

# %%
columns = ["Model", "source", "Tag", "Num Correct", "Num Questions", "% Accuracy"]
rows = []

for source in sources:
  for tag in tags:
    for model in models:
      if tag not in "gk, cs":
        continue
      res = [row["correct"] == "Y" for row in key_row.values()
      if row["model"] == model  and id_question[row["question_id"]]["source"] == source and tag in id_question[row["question_id"]]["labels"] and row["prompt_id"] == "1"]
      if not res:
        continue
      rows.append([model, source, tag, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                               Model        source Tag  Num Correct  \
# 0   FreedomIntelligence/Apollo-0.5B  case_studies  gk           28
# 1     johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  gk           43
# 2           skumar9/Llama-medx_v3.2  case_studies  gk           48
# 3     microsoft/Phi-4-mini-instruct  case_studies  gk           62
# 4              gemini-2.0-flash-001  case_studies  gk           66
# 5   FreedomIntelligence/Apollo-0.5B  case_studies  cs           49
# 6     johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  cs           59
# 7           skumar9/Llama-medx_v3.2  case_studies  cs           61
# 8     microsoft/Phi-4-mini-instruct  case_studies  cs           71
# 9              gemini-2.0-flash-001  case_studies  cs           76
# 10  FreedomIntelligence/Apollo-0.5B         apdvs  gk           10
# 11    johnsnowlabs/JSL-MedPhi2-2.7B         apdvs  gk           10
# 12          skumar9/Llama-medx_v3.2         apdvs  gk           12
# 13    microsoft/Phi-4-mini-instruct         apdvs  gk           14
# 14             gemini-2.0-flash-001         apdvs  gk           14
# 15  FreedomIntelligence/Apollo-0.5B         apdvs  cs           16
# 16    johnsnowlabs/JSL-MedPhi2-2.7B         apdvs  cs           24
# 17          skumar9/Llama-medx_v3.2         apdvs  cs           27
# 18    microsoft/Phi-4-mini-instruct         apdvs  cs           29
# 19             gemini-2.0-flash-001         apdvs  cs           34
# 20  FreedomIntelligence/Apollo-0.5B          racs  gk            2
# 21    johnsnowlabs/JSL-MedPhi2-2.7B          racs  gk            8
# 22          skumar9/Llama-medx_v3.2          racs  gk            4
# 23    microsoft/Phi-4-mini-instruct          racs  gk            9
# 24             gemini-2.0-flash-001          racs  gk           30
# 25  FreedomIntelligence/Apollo-0.5B          prep  cs            4
# 26    johnsnowlabs/JSL-MedPhi2-2.7B          prep  cs            7
# 27          skumar9/Llama-medx_v3.2          prep  cs            9
# 28    microsoft/Phi-4-mini-instruct          prep  cs            8
# 29             gemini-2.0-flash-001          prep  cs           11
# 30  FreedomIntelligence/Apollo-0.5B          abvm  gk            0
# 31    johnsnowlabs/JSL-MedPhi2-2.7B          abvm  gk            1
# 32          skumar9/Llama-medx_v3.2          abvm  gk            1
# 33    microsoft/Phi-4-mini-instruct          abvm  gk            2
# 34             gemini-2.0-flash-001          abvm  gk            4
#
#     Num Questions  % Accuracy
# 0             155        18.1
# 1             155        27.7
# 2             155        31.0
# 3             155        40.0
# 4             155        42.6
# 5             162        30.2
# 6             162        36.4
# 7             162        37.7
# 8             162        43.8
# 9             162        46.9
# 10             20        50.0
# 11             20        50.0
# 12             20        60.0
# 13             20        70.0
# 14             20        70.0
# 15             41        39.0
# 16             41        58.5
# 17             41        65.9
# 18             41        70.7
# 19             41        82.9
# 20             56         3.6
# 21             56        14.3
# 22             56         7.1
# 23             56        16.1
# 24             56        53.6
# 25             13        30.8
# 26             13        53.8
# 27             13        69.2
# 28             13        61.5
# 29             13        84.6
# 30              4         0.0
# 31              4        25.0
# 32              4        25.0
# 33              4        50.0
# 34              4       100.0

# %%
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
#raw_tags = []
#[raw_tags.extend([x.strip() for x in q["tags"]]) for q in id_question.values()]
#tags = sorted(list(set(raw_tags)), key=lambda x: raw_tags.count(x), reverse=True)
#print(tags)
columns = ["Model", "source", "Tag", "#c>1", "Num Correct", "Num Questions", "% Accuracy"]
rows = []
for model in models:
  for source in sources:
    for tag in tags:
      if tag not in "gk, cs":
        continue
      res = [row["correct"] == "Y" for row in key_row.values()
      if row["model"] == model  and  len(id_question[row["question_id"]]["answer"].split(",")) == 1 and
        id_question[row["question_id"]]["source"] == source and tag in id_question[row["question_id"]]["labels"] and row["prompt_id"] == "1"]
      if res:
        rows.append([model, source, tag, "1", sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
      res = [row["correct"] == "Y" for row in key_row.values()
      if row["model"] == model  and  len(id_question[row["question_id"]]["answer"].split(",")) > 1 and
        id_question[row["question_id"]]["source"] == source and tag in id_question[row["question_id"]]["labels"] and row["prompt_id"] == "1"]
      if res:
        rows.append([model, source, tag, ">1", sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                               Model        source Tag #c>1  Num Correct  \
# 0   FreedomIntelligence/Apollo-0.5B  case_studies  gk    1           24
# 1   FreedomIntelligence/Apollo-0.5B  case_studies  gk   >1            4
# 2   FreedomIntelligence/Apollo-0.5B  case_studies  cs    1           47
# 3   FreedomIntelligence/Apollo-0.5B  case_studies  cs   >1            2
# 4   FreedomIntelligence/Apollo-0.5B         apdvs  gk    1           10
# 5   FreedomIntelligence/Apollo-0.5B         apdvs  cs    1           16
# 6   FreedomIntelligence/Apollo-0.5B          racs  gk    1            1
# 7   FreedomIntelligence/Apollo-0.5B          racs  gk   >1            1
# 8   FreedomIntelligence/Apollo-0.5B          prep  cs    1            4
# 9   FreedomIntelligence/Apollo-0.5B          abvm  gk    1            0
# 10  FreedomIntelligence/Apollo-0.5B          abvm  gk   >1            0
# 11    johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  gk    1           34
# 12    johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  gk   >1            9
# 13    johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  cs    1           55
# 14    johnsnowlabs/JSL-MedPhi2-2.7B  case_studies  cs   >1            4
# 15    johnsnowlabs/JSL-MedPhi2-2.7B         apdvs  gk    1           10
# 16    johnsnowlabs/JSL-MedPhi2-2.7B         apdvs  cs    1           24
# 17    johnsnowlabs/JSL-MedPhi2-2.7B          racs  gk    1            0
# 18    johnsnowlabs/JSL-MedPhi2-2.7B          racs  gk   >1            8
# 19    johnsnowlabs/JSL-MedPhi2-2.7B          prep  cs    1            7
# 20    johnsnowlabs/JSL-MedPhi2-2.7B          abvm  gk    1            1
# 21    johnsnowlabs/JSL-MedPhi2-2.7B          abvm  gk   >1            0
# 22          skumar9/Llama-medx_v3.2  case_studies  gk    1           42
# 23          skumar9/Llama-medx_v3.2  case_studies  gk   >1            6
# 24          skumar9/Llama-medx_v3.2  case_studies  cs    1           61
# 25          skumar9/Llama-medx_v3.2  case_studies  cs   >1            0
# 26          skumar9/Llama-medx_v3.2         apdvs  gk    1           12
# 27          skumar9/Llama-medx_v3.2         apdvs  cs    1           27
# 28          skumar9/Llama-medx_v3.2          racs  gk    1            3
# 29          skumar9/Llama-medx_v3.2          racs  gk   >1            1
# 30          skumar9/Llama-medx_v3.2          prep  cs    1            9
# 31          skumar9/Llama-medx_v3.2          abvm  gk    1            1
# 32          skumar9/Llama-medx_v3.2          abvm  gk   >1            0
# 33    microsoft/Phi-4-mini-instruct  case_studies  gk    1           45
# 34    microsoft/Phi-4-mini-instruct  case_studies  gk   >1           17
# 35    microsoft/Phi-4-mini-instruct  case_studies  cs    1           61
# 36    microsoft/Phi-4-mini-instruct  case_studies  cs   >1           10
# 37    microsoft/Phi-4-mini-instruct         apdvs  gk    1           14
# 38    microsoft/Phi-4-mini-instruct         apdvs  cs    1           29
# 39    microsoft/Phi-4-mini-instruct          racs  gk    1            0
# 40    microsoft/Phi-4-mini-instruct          racs  gk   >1            9
# 41    microsoft/Phi-4-mini-instruct          prep  cs    1            8
# 42    microsoft/Phi-4-mini-instruct          abvm  gk    1            2
# 43    microsoft/Phi-4-mini-instruct          abvm  gk   >1            0
# 44             gemini-2.0-flash-001  case_studies  gk    1           43
# 45             gemini-2.0-flash-001  case_studies  gk   >1           23
# 46             gemini-2.0-flash-001  case_studies  cs    1           65
# 47             gemini-2.0-flash-001  case_studies  cs   >1           11
# 48             gemini-2.0-flash-001         apdvs  gk    1           14
# 49             gemini-2.0-flash-001         apdvs  cs    1           34
# 50             gemini-2.0-flash-001          racs  gk    1            4
# 51             gemini-2.0-flash-001          racs  gk   >1           26
# 52             gemini-2.0-flash-001          prep  cs    1           11
# 53             gemini-2.0-flash-001          abvm  gk    1            3
# 54             gemini-2.0-flash-001          abvm  gk   >1            1
#
#     Num Questions  % Accuracy
# 0              74        32.4
# 1              81         4.9
# 2             109        43.1
# 3              53         3.8
# 4              20        50.0
# 5              41        39.0
# 6               5        20.0
# 7              51         2.0
# 8              13        30.8
# 9               3         0.0
# 10              1         0.0
# 11             74        45.9
# 12             81        11.1
# 13            109        50.5
# 14             53         7.5
# 15             20        50.0
# 16             41        58.5
# 17              5         0.0
# 18             51        15.7
# 19             13        53.8
# 20              3        33.3
# 21              1         0.0
# 22             74        56.8
# 23             81         7.4
# 24            109        56.0
# 25             53         0.0
# 26             20        60.0
# 27             41        65.9
# 28              5        60.0
# 29             51         2.0
# 30             13        69.2
# 31              3        33.3
# 32              1         0.0
# 33             74        60.8
# 34             81        21.0
# 35            109        56.0
# 36             53        18.9
# 37             20        70.0
# 38             41        70.7
# 39              5         0.0
# 40             51        17.6
# 41             13        61.5
# 42              3        66.7
# 43              1         0.0
# 44             74        58.1
# 45             81        28.4
# 46            109        59.6
# 47             53        20.8
# 48             20        70.0
# 49             41        82.9
# 50              5        80.0
# 51             51        51.0
# 52             13        84.6
# 53              3       100.0
# 54              1       100.0

# %%
raw_num_answers = [len(q["answer"].split(",")) for q in id_question.values() if any(k[1] == q["question_id"] for k in key_row)]
num_answers = sorted(list(set(raw_num_answers)), key=lambda x: raw_num_answers.count(x), reverse=True)
columns = ["Model", "Num Answers", "Num Q Correct", "Num Questions", "% Accuracy"]
rows = []
for model in models:
  for num in num_answers:
    res = [row["correct"] == "Y" for row in key_row.values()
    if row["model"] == model and len(id_question[row["question_id"]]["answer"].split(",")) == num and row["prompt_id"] == "1"]
    rows.append([model, num, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                               Model  Num Answers  Num Q Correct  \
# 0   FreedomIntelligence/Apollo-0.5B            1            102
# 1   FreedomIntelligence/Apollo-0.5B            2              0
# 2   FreedomIntelligence/Apollo-0.5B            3              0
# 3   FreedomIntelligence/Apollo-0.5B            4              5
# 4   FreedomIntelligence/Apollo-0.5B            5              2
# 5   FreedomIntelligence/Apollo-0.5B            7              0
# 6   FreedomIntelligence/Apollo-0.5B            6              0
# 7     johnsnowlabs/JSL-MedPhi2-2.7B            1            131
# 8     johnsnowlabs/JSL-MedPhi2-2.7B            2              9
# 9     johnsnowlabs/JSL-MedPhi2-2.7B            3              8
# 10    johnsnowlabs/JSL-MedPhi2-2.7B            4              3
# 11    johnsnowlabs/JSL-MedPhi2-2.7B            5              1
# 12    johnsnowlabs/JSL-MedPhi2-2.7B            7              0
# 13    johnsnowlabs/JSL-MedPhi2-2.7B            6              0
# 14          skumar9/Llama-medx_v3.2            1            155
# 15          skumar9/Llama-medx_v3.2            2              0
# 16          skumar9/Llama-medx_v3.2            3              0
# 17          skumar9/Llama-medx_v3.2            4              5
# 18          skumar9/Llama-medx_v3.2            5              2
# 19          skumar9/Llama-medx_v3.2            7              0
# 20          skumar9/Llama-medx_v3.2            6              0
# 21    microsoft/Phi-4-mini-instruct            1            159
# 22    microsoft/Phi-4-mini-instruct            2             18
# 23    microsoft/Phi-4-mini-instruct            3              8
# 24    microsoft/Phi-4-mini-instruct            4              8
# 25    microsoft/Phi-4-mini-instruct            5              2
# 26    microsoft/Phi-4-mini-instruct            7              0
# 27    microsoft/Phi-4-mini-instruct            6              0
# 28             gemini-2.0-flash-001            1            174
# 29             gemini-2.0-flash-001            2             26
# 30             gemini-2.0-flash-001            3             22
# 31             gemini-2.0-flash-001            4             10
# 32             gemini-2.0-flash-001            5              2
# 33             gemini-2.0-flash-001            7              0
# 34             gemini-2.0-flash-001            6              1
#
#     Num Questions  % Accuracy
# 0             265        38.5
# 1              78         0.0
# 2              57         0.0
# 3              36        13.9
# 4              12        16.7
# 5               2         0.0
# 6               1         0.0
# 7             265        49.4
# 8              78        11.5
# 9              57        14.0
# 10             36         8.3
# 11             12         8.3
# 12              2         0.0
# 13              1         0.0
# 14            265        58.5
# 15             78         0.0
# 16             57         0.0
# 17             36        13.9
# 18             12        16.7
# 19              2         0.0
# 20              1         0.0
# 21            265        60.0
# 22             78        23.1
# 23             57        14.0
# 24             36        22.2
# 25             12        16.7
# 26              2         0.0
# 27              1         0.0
# 28            265        65.7
# 29             78        33.3
# 30             57        38.6
# 31             36        27.8
# 32             12        16.7
# 33              2         0.0
# 34              1       100.0

# %%
# filter to single correct answer, no paper specific questions
#models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
columns = ["Model", "Num Correct", "Num Questions", "% Accuracy"]
rows = []
for model in models:
  res = [row["correct"] == "Y" for row in key_row.values()
  if (row["model"] == model and len(id_question[row["question_id"]]["answer"].split(",")) == 1 and row["prompt_id"] == "1")]
  rows.append([model, sum(res), len(res), round(100*sum(res)/len(res) if res else 0, 1)])
pd.DataFrame(rows, columns=columns)
# Out:
#                              Model  Num Correct  Num Questions  % Accuracy
# 0  FreedomIntelligence/Apollo-0.5B          102            265        38.5
# 1    johnsnowlabs/JSL-MedPhi2-2.7B          131            265        49.4
# 2          skumar9/Llama-medx_v3.2          155            265        58.5
# 3    microsoft/Phi-4-mini-instruct          159            265        60.0
# 4             gemini-2.0-flash-001          174            265        65.7

# %%
for id, prompt in pre_prompts.items():
  #print(id)
  print(prompt)
  print("")
# Out:
# You are a vascular surgeon responsible for teaching medical students. Provide concise, medically accurate, and ethically appropriate answers based on current standards of care. Focus only on clinical education relevant to surgery.
#
# You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students. Provide useful, complete, and scientifically-grounded answers to clinical questions relevant to surgery and medical care.
#
# Answer the following multiple choice question from the medical domain based on these instructions. Choose one or more of the provided answer choices which are correct and output them under the heading "Answer".
#
# You are a helpful medical knowledge assistant specializing in teaching vascular surgery to medical students.
# Answer the following multiple choice question from the medical domain based on the following instructions.
# 1. Select the one or more correct options and provide the option(s) under the heading "Answer".
# 2. Always select one or more of the provided options as the answer.
# 3. If the options are ambiguous or the question does not have enough context, select the ones that best answer the question.
# 4. If the question is not clinically relevant to vascular surgery, please respond with, "I'm sorry, I cannot answer this question."
#
# Question:
# Which of the following is the most common site for peripheral arterial disease (PAD)?
# A. Carotid artery
# B. Femoral-popliteal artery
# C. Renal artery
# D. Subclavian artery
# Answer:
# B. Femoral-popliteal artery
#
# Question:
# Which of the following are common risk factors for developing an abdominal aortic aneurysm (AAA)?
# A. Smoking
# B. Male gender
# C. Hypertension
# D. Type 1 diabetes mellitus
# E. Family history of AAA
# Answer:
# A. Smoking
# B. Male gender
# C. Hypertension
# E. Family history of AAA

# %%
models = ["FreedomIntelligence/Apollo-0.5B", "johnsnowlabs/JSL-MedPhi2-2.7B", "skumar9/Llama-medx_v3.2"]
raw_source = [q["source"] for q in id_question.values()]
sources = sorted(list(set(raw_source)), key=lambda x: raw_source.count(x), reverse=True)

columns = ["Source", "Tag", "Num Questions"]
rows = []
for source in sources:
  for tag in [''] + tags:
    res = [row for row in key_row.values()
    if id_question[row["question_id"]]["source"] == source and row["prompt_id"] == "1" and row["model"] == models[0] and tag in " ".join(id_question[row["question_id"]]["tags"])]
    rows.append([source, tag, len(res)])
pd.DataFrame(rows, columns=columns)
# Out:
#           Source Tag  Num Questions
# 0   case_studies                317
# 1   case_studies  gk            155
# 2   case_studies  cs            162
# 3   case_studies  lq              0
# 4   case_studies  sq              0
# 5   case_studies  fu              0
# 6          apdvs                 61
# 7          apdvs  gk             20
# 8          apdvs  cs             41
# 9          apdvs  lq             13
# 10         apdvs  sq             13
# 11         apdvs  fu              2
# 12          racs                 56
# 13          racs  gk             56
# 14          racs  cs              0
# 15          racs  lq              0
# 16          racs  sq              0
# 17          racs  fu              0
# 18          prep                 13
# 19          prep  gk              0
# 20          prep  cs             13
# 21          prep  lq              0
# 22          prep  sq              0
# 23          prep  fu              0
# 24          abvm                  4
# 25          abvm  gk              4
# 26          abvm  cs              0
# 27          abvm  lq              0
# 28          abvm  sq              0
# 29          abvm  fu              0
